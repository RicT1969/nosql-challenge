# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : {'$eq' : 20},  }

# Use count_documents to display the number of documents in the result
print("Number of records in result:", establishments.count_documents(query))
# Out:
# Number of records in result: 41

# %%
# Display the first document using pprint

pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646ff9e34922150fc439dc07'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results = establishments.find(query)
hygiene_equal_20_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene_equal_20_df))
# Out:
# Rows in DataFrame:  41

# %%
# Display the first 10 rows of the DataFrame
hygiene_equal_20_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  646ff9e34922150fc439dc07   110681                  0
# 1  646ff9e34922150fc439df88   612039                  0
# 2  646ff9e34922150fc439e297   730933                  0
# 3  646ff9e34922150fc439e477   172735                  0
# 4  646ff9e34922150fc439e491   172953                  0
# 5  646ff9e34922150fc439ee2b   512854                  0
# 6  646ff9e34922150fc439f056  1537089                  0
# 7  646ff9e34922150fc43a057a   155648                  0
# 8  646ff9e34922150fc43a09bf  1012883                  0
# 9  646ff9e34922150fc43a11cc   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

query = {'LocalAuthorityName' : {'$regex' : 'London'}, 'RatingValue' : {'$gte' : '4'}}

projection = {'BusinessName': 1, '_id' : 0}

results = establishments.find(query, projection)
# Use count_documents to display the number of documents in the result

# print("Number of records in result:", establishments.count_documents(query))
for row in results:
    pprint(row)
# Out:
# {'BusinessName': "Charlie's"}
# {'BusinessName': 'Mv City Cruises Erasmus'}
# {'BusinessName': 'Benfleet Motor Yacht Club'}
# {'BusinessName': 'Tilbury Seafarers Centre'}
# {'BusinessName': 'Coombs Catering t/a The Lock and Key'}
# {'BusinessName': 'Mv Valulla'}
# {'BusinessName': 'Tereza Joanne'}
# {'BusinessName': 'Froottree'}
# {'BusinessName': 'Brick Lane Brews'}
# {'BusinessName': 'The Nuance Group (UK) Limited'}
# {'BusinessName': 'WH Smith'}
# {'BusinessName': 'City Bar & Grill'}
# {'BusinessName': 'Caffè Nero'}
# {'BusinessName': 'Jet Centre'}
# {'BusinessName': 'Mv Sunborn Yacht Hotel'}
# {'BusinessName': 'Good Hotel London'}
# {'BusinessName': 'La Nonna lina'}
# {'BusinessName': 'Wake Up Docklands Limited'}
# {'BusinessName': 'MV Venus Clipper'}
# {'BusinessName': 'MV Typhoon clipper'}
# {'BusinessName': 'MV Moon clipper'}
# {'BusinessName': 'MV Jupiter clipper'}
# {'BusinessName': 'MV Monsoon clipper'}
# {'BusinessName': 'MV Meteor clipper'}
# {'BusinessName': 'MV Tornado clipper'}
# {'BusinessName': 'MV Cyclone clipper'}
# {'BusinessName': 'MV Neptune clipper'}
# {'BusinessName': 'MV Hurricane clipper'}
# {'BusinessName': 'MV Galaxy clipper'}
# {'BusinessName': 'MV Sun clipper'}
# {'BusinessName': 'MV Mercury clipper'}
# {'BusinessName': 'MV Aurora clipper'}
# {'BusinessName': 'Canary Wharf 1V'}
# {'BusinessName': 'Mv Storm Clipper'}

# %%
# Display the first document in the results using pprint

pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646ff9e34922150fc439f624'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Check that the new restaurant was inserted
query = establishments.count_documents({'BusinessName' : 'Coombs Catering t/a The Lock and Keys'})

query
# Out:
# 0

# %%
# Convert the result to a Pandas DataFrame

London = establishments.find(query)
London_rating_4plus_df = pd.DataFrame(London)


# Display the number of rows in the DataFrame

print("Rows in DataFrame: ", len(London_rating_4plus_df))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[287], line 3
#       1 # Convert the result to a Pandas DataFrame
# ----> 3 London = establishments.find(query)
#       4 London_rating_4plus_df = pd.DataFrame(London)
#       7 # Display the number of rows in the DataFrame
#
# File c:\Users\richa\anaconda3\envs\myenvpandas\Lib\site-packages\pymongo\collection.py:1532, in Collection.find(self, *args, **kwargs)
#    1332 def find(self, *args, **kwargs):
#    1333     """Query the database.
#    1334
#    1335     The `filter` argument is a prototype document that all results
#    (...)
#    1530
#    1531     """
# -> 1532     return Cursor(self, *args, **kwargs)
#
# File c:\Users\richa\anaconda3\envs\myenvpandas\Lib\site-packages\pymongo\cursor.py:173, in Cursor.__init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation, hint, max_scan, max_time_ms, max, min, return_key, show_record_id, snapshot, comment, session, allow_disk_use)
#     170 if spec is None:
#     171     spec = {}
# --> 173 validate_is_mapping("filter", spec)
#     174 if not isinstance(skip, int):
#     175     raise TypeError("skip must be an instance of int")
#
# File c:\Users\richa\anaconda3\envs\myenvpandas\Lib\site-packages\pymongo\common.py:495, in validate_is_mapping(option, value)
#     493 """Validate the type of method arguments that expect a document."""
#     494 if not isinstance(value, abc.Mapping):
# --> 495     raise TypeError("%s must be an instance of dict, bson.son.SON, or "
#     496                     "any other type that inherits from "
#     497                     "collections.Mapping" % (option,))
#
# TypeError: filter must be an instance of dict, bson.son.SON, or any other type that inherits from collections.Mapping

# %%
# Display the first 10 rows of the DataFrame

London_rating_4plus_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
# distance for search range defined


degree_search = 0.01
latitude = 51.369321
longitude = 0.08384


query = { 
    'geocode.latitude' : {'$gte' : latitude - degree_search, '$lte' : latitude + degree_search}, 
    'geocode.longitude' : {'$gte' : longitude - degree_search, '$lte' : longitude + degree_search}, 
    'RatingValue' : '5'
    }
sort = [('scores.Hygiene', 1)] 
limit = 5


nearby_restuarants = list(establishments.find(query).sort(sort).limit(limit))

# Pretty print the results
pprint(nearby_restuarants)
# Out:
# [{'AddressLine1': '2 - 3 Crescent Way',
#   'AddressLine2': 'Orpington',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Co-op',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4642.473269874587,
#   'FHRSID': 357720,
#   'LocalAuthorityBusinessID': '00000/0001/0/630',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR6 9LP',
#   'RatingDate': '2018-12-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('646ff9e44922150fc43a1fcc'),
#   'geocode': {'latitude': 51.360803, 'longitude': 0.088136},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357720',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '9 Crescent Way',
#   'AddressLine2': 'Orpington',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Porters Produce',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4642.473269874587,
#   'FHRSID': 357724,
#   'LocalAuthorityBusinessID': '00000/0001/0/638',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR6 9LP',
#   'RatingDate': '2019-11-27T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('646ff9e44922150fc43a1fd1'),
#   'geocode': {'latitude': 51.360803, 'longitude': 0.088136},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357724',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Holy Innocents Presbytery',
#   'AddressLine2': 'Strickland Way',
#   'AddressLine3': 'Orpington',
#   'AddressLine4': '',
#   'BusinessName': 'Holy Innocents Catholic Church',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4642.492258494412,
#   'FHRSID': 554943,
#   'LocalAuthorityBusinessID': '04/00122/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR6 9UE',
#   'RatingDate': '2018-10-31T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('646ff9e44922150fc43a1fdd'),
#   'geocode': {'latitude': 51.364249, 'longitude': 0.091066},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/554943',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Caritas House',
#   'AddressLine2': 'Tregony Road',
#   'AddressLine3': 'Orpington',
#   'AddressLine4': '',
#   'BusinessName': "St Christopher's Bromley",
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4642.405193823783,
#   'FHRSID': 358298,
#   'LocalAuthorityBusinessID': '04/00154/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR6 9XA',
#   'RatingDate': '2022-08-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('646ff9e44922150fc43a1f9d'),
#   'geocode': {'latitude': 51.364269, 'longitude': 0.093466},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/358298',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '7 Crescent Way',
#   'AddressLine2': 'Orpington',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Tams Pizza, Food & Wine',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4642.473269874587,
#   'FHRSID': 357723,
#   'LocalAuthorityBusinessID': '00000/0001/0/635',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR6 9LP',
#   'RatingDate': '2020-10-29T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('646ff9e44922150fc43a1fce'),
#   'geocode': {'latitude': 51.360803, 'longitude': 0.088136},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357723',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}]

# %%
# Convert result to Pandas DataFrame

nearby_restuarants_df = pd.DataFrame(nearby_restuarants)

print("Rows in DataFrame: ", len(nearby_restuarants_df))


# Display the number of rows in the DataFrame?

nearby_restuarants_df.head()
# Out:
# Rows in DataFrame:  5
#                         _id  FHRSID  ChangesByServerID  \
# 0  646ff9e44922150fc43a1fcc  357720                  0
# 1  646ff9e44922150fc43a1fd1  357724                  0
# 2  646ff9e44922150fc43a1fdd  554943                  0
# 3  646ff9e44922150fc43a1f9d  358298                  0
# 4  646ff9e44922150fc43a1fce  357723                  0
#
#   LocalAuthorityBusinessID                    BusinessName  \
# 0         00000/0001/0/630                           Co-op
# 1         00000/0001/0/638                 Porters Produce
# 2           04/00122/MIXED  Holy Innocents Catholic Church
# 3           04/00154/MIXED        St Christopher's Bromley
# 4         00000/0001/0/635         Tams Pizza, Food & Wine
#
#                             BusinessType  BusinessTypeID  \
# 0  Retailers - supermarkets/hypermarkets            7840
# 1                      Retailers - other            4613
# 2                Other catering premises            7841
# 3                        Caring Premises               5
# 4                      Retailers - other            4613
#
#                 AddressLine1    AddressLine2 AddressLine3  ...  \
# 0         2 - 3 Crescent Way       Orpington               ...
# 1             9 Crescent Way       Orpington               ...
# 2  Holy Innocents Presbytery  Strickland Way    Orpington  ...
# 3              Caritas House    Tregony Road    Orpington  ...
# 4             7 Crescent Way       Orpington               ...
#
#        LocalAuthorityWebSite LocalAuthorityEmailAddress  \
# 0  http://www.bromley.gov.uk        food@bromley.gov.uk
# 1  http://www.bromley.gov.uk        food@bromley.gov.uk
# 2  http://www.bromley.gov.uk        food@bromley.gov.uk
# 3  http://www.bromley.gov.uk        food@bromley.gov.uk
# 4  http://www.bromley.gov.uk        food@bromley.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                           geocode RightToReply     Distance  \
# 0  {'longitude': 0.088136, 'latitude': 51.360803}               4642.473270
# 1  {'longitude': 0.088136, 'latitude': 51.360803}               4642.473270
# 2  {'longitude': 0.091066, 'latitude': 51.364249}               4642.492258
# 3  {'longitude': 0.093466, 'latitude': 51.364269}               4642.405194
# 4  {'longitude': 0.088136, 'latitude': 51.360803}               4642.473270
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id' : '$LocalAuthorityName', 
                          'count': { '$sum': 1 }}}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1, '_id': 1 }}

# Print the number of documents in the result
pipeline = [match_query, group_query, sort_values]

hygenic_establishments = list(establishments.aggregate(pipeline))

# Print the first 10 results
print("Number of establishments in results: ", len(hygenic_establishments))

pprint(hygenic_establishments[0:10])
# Out:
# Number of establishments in results:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygenic_establishments_df = pd.DataFrame(hygenic_establishments)


# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygenic_establishments_df))
# Out:
# Rows in DataFrame:  55

# %%
# Display the first 10 rows of the DataFrame
hygenic_establishments_df.head(10)
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
